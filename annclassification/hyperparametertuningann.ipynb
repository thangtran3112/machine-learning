W external/local_xla/xla/tsl/framework/bfc_allocator.cc:306] Allocator (GPU_0_bfc) ran out of memory trying to allocate 16.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-12-07 17:45:46.833341: W tensorflow/core/framework/op_kernel.cc:1841] OP_REQUIRES failed at xla_ops.cc:577 : RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777344 bytes.
# 2024-12-07 17:45:46.833404: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 16777344 bytes.
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1733622346.914831   49222 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  58/167 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2077 - loss: 0.9312Epoch 1/50
# 145/167 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3593 - loss: 0.8254
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3903 - loss: 0.8058
# Epoch 2/50
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#  96/167 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7866 - loss: 0.5069
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 166/167 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7878 - loss: 0.5003
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# ...
#     self._fit(
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     except TypeError as e:
# tensorflow.python.framework.errors_impl.ResourceExhaustedError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/multiprocessing/process.py", line 108, in run
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py", line 463, in _process_worker
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/joblib/parallel.py", line 598, in __call__
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/sklearn/utils/parallel.py", line 136, in __call__
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py", line 1501, in fit
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py", line 770, in fit
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py", line 938, in _fit
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 368, in fit
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 216, in function
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 129, in multi_step_on_iterator
#
# Out of memory while trying to allocate 16777344 bytes.
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_multi_step_on_iterator_6930]
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py", line 1501, in fit
#     super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py", line 770, in fit
#     self._fit(
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py", line 938, in _fit
#     self._fit_keras_model(
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#     hist = self.model_.fit(x=X, y=y, **fit_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/tensorflow/python/eager/execute.py", line 59, in quick_execute
#     except TypeError as e:
# tensorflow.python.framework.errors_impl.ResourceExhaustedError: Graph execution error:
#
# Detected at node StatefulPartitionedCall defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/joblib/externals/loky/backend/popen_loky_posix.py", line 180, in <module>
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/multiprocessing/process.py", line 108, in run
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py", line 463, in _process_worker
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/joblib/parallel.py", line 598, in __call__
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/sklearn/utils/parallel.py", line 136, in __call__
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py", line 1501, in fit
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py", line 770, in fit
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py", line 938, in _fit
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py", line 535, in _fit_keras_model
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 368, in fit
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 216, in function
#
#   File "/home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py", line 129, in multi_step_on_iterator
#
# Out of memory while trying to allocate 16777728 bytes.
# 	 [[{{node StatefulPartitionedCall}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_multi_step_on_iterator_8324]
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1102: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /home/thangtran3112/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[17], line 6
#       4 # Perform grid search
#       5 grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3,verbose=1)
# ----> 6 grid_result = grid.fit(X_train, y_train)
#       8 # Print the best parameters
#       9 print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
#
# File ~/machine-learning/annclassification/venv/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/machine-learning/annclassification/venv/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1056, in BaseSearchCV.fit(self, X, y, **params)
#    1054 refit_start_time = time.time()
#    1055 if y is not None:
# -> 1056     self.best_estimator_.fit(X, y, **routed_params.estimator.fit)
#    1057 else:
#    1058     self.best_estimator_.fit(X, **routed_params.estimator.fit)
#
# File ~/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:1501, in KerasClassifier.fit(self, X, y, sample_weight, **kwargs)
#    1499     sample_weight = 1 if sample_weight is None else sample_weight
#    1500     sample_weight *= compute_sample_weight(class_weight=self.class_weight, y=y)
# -> 1501 super().fit(X=X, y=y, sample_weight=sample_weight, **kwargs)
#    1502 return self
#
# File ~/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:770, in BaseWrapper.fit(self, X, y, sample_weight, **kwargs)
#     765 kwargs["epochs"] = kwargs.get(
#     766     "epochs", getattr(self, "fit__epochs", self.epochs)
#     767 )
#     768 kwargs["initial_epoch"] = kwargs.get("initial_epoch", 0)
# --> 770 self._fit(
#     771     X=X,
#     772     y=y,
#     773     sample_weight=sample_weight,
#     774     warm_start=self.warm_start,
#     775     **kwargs,
#     776 )
#     778 return self
#
# File ~/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:925, in BaseWrapper._fit(self, X, y, sample_weight, warm_start, epochs, initial_epoch, **kwargs)
#     923 # Data checks
#     924 if not ((self.warm_start or warm_start) and self.initialized_):
# --> 925     X, y = self._initialize(X, y)
#     926 else:
#     927     X, y = self._validate_data(X, y)
#
# File ~/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:862, in BaseWrapper._initialize(self, X, y)
#     859 feature_meta = getattr(self.feature_encoder, "get_metadata", dict)()
#     860 vars(self).update(**feature_meta)
# --> 862 self.model_ = self._build_keras_model()
#     863 self._initialize_callbacks()
#     865 return X, y
#
# File ~/machine-learning/annclassification/venv/lib/python3.12/site-packages/scikeras/wrappers.py:433, in BaseWrapper._build_keras_model(self)
#     431         model = final_build_fn(**build_params)
#     432 else:
# --> 433     model = final_build_fn(**build_params)
#     435 return model
#
# Cell In[14], line 5, in create_model(neurons, layers)
#       3 def create_model(neurons=32,layers=1):
#       4     model=Sequential()
# ----> 5     model.add(Dense(neurons,activation='relu',input_shape=(X_train.shape[1],)))
#       7     for _ in range(layers-1):
#       8         model.add(Dense(neurons,activation='relu'))
#
# File ~/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/models/sequential.py:122, in Sequential.add(self, layer, rebuild)
#     120 self._layers.append(layer)
#     121 if rebuild:
# --> 122     self._maybe_rebuild()
#     123 else:
#     124     self.built = False
#
# File ~/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/models/sequential.py:141, in Sequential._maybe_rebuild(self)
#     139 if isinstance(self._layers[0], InputLayer) and len(self._layers) > 1:
#     140     input_shape = self._layers[0].batch_shape
# --> 141     self.build(input_shape)
#     142 elif hasattr(self._layers[0], "input_shape") and len(self._layers) > 1:
#     143     # We can build the Sequential model if the first layer has the
#     144     # `input_shape` property. This is most commonly found in Functional
#     145     # model.
#     146     input_shape = self._layers[0].input_shape
#
# File ~/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/layers/layer.py:226, in Layer.__new__.<locals>.build_wrapper(*args, **kwargs)
#     224 with obj._open_name_scope():
#     225     obj._path = current_path()
# --> 226     original_build_method(*args, **kwargs)
#     227 # Record build config.
#     228 signature = inspect.signature(original_build_method)
#
# File ~/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/models/sequential.py:187, in Sequential.build(self, input_shape)
#     185 for layer in self._layers[1:]:
#     186     try:
# --> 187         x = layer(x)
#     188     except NotImplementedError:
#     189         # Can happen if shape inference is not implemented.
#     190         # TODO: consider reverting inbound nodes on layers processed.
#     191         return
#
# File ~/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/machine-learning/annclassification/venv/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:141, in convert_to_tensor(x, dtype, sparse)
#     136 if not tf.is_tensor(x):
#     137     if dtype == "bool" or is_int_dtype(dtype):
#     138         # TensorFlow conversion is stricter than other backends, it does not
#     139         # allow ints for bools or floats for ints. We convert without dtype
#     140         # and cast instead.
# --> 141         x = tf.convert_to_tensor(x)
#     142         return tf.cast(x, dtype)
#     143     return tf.convert_to_tensor(x, dtype=dtype)
#
# InternalError: cudaSetDevice() on GPU:0 failed. Status: CUDA-capable device(s) is/are busy or unavailable
